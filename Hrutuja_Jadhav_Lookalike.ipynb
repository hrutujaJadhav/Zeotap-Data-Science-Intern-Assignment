# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity

# Load data
customers = pd.read_csv("Customers.csv")
products = pd.read_csv("Products.csv")
transactions = pd.read_csv("Transactions.csv")

# %%
# Merge datasets for a comprehensive view
merged_data = transactions.merge(customers, on="CustomerID").merge(products, on="ProductID")

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price_x          1000 non-null   float64
#  7   CustomerName     1000 non-null   object
#  8   Region           1000 non-null   object
#  9   SignupDate       1000 non-null   object
#  10  ProductName      1000 non-null   object
#  11  Category         1000 non-null   object
#  12  Price_y          1000 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 109.4+ KB

# %%
# Aggregate transaction data by customer
customer_features = merged_data.groupby("CustomerID").agg({
    "TotalValue": "sum",
    "Quantity": "sum",
    "Price_x": "mean",
    "Category": lambda x: ",".join(x),
    "Region": "first"
}).reset_index()

# %%
# Encode categorical features
encoder = LabelEncoder()
customer_features["Region"] = encoder.fit_transform(customer_features["Region"])
customer_features["Category"] = encoder.fit_transform(customer_features["Category"])

# %%
# Normalize numeric features
numeric_features = ["TotalValue", "Quantity", "Price_x"]
customer_features[numeric_features] = customer_features[numeric_features].apply(lambda x: (x - x.mean()) / x.std())
print(customer_features[numeric_features])
# Out:
#      TotalValue  Quantity   Price_x
# 0     -0.061546 -0.121726  0.094432
# 1     -0.875535 -0.446873 -0.901742
# 2     -0.404836  0.203421 -1.091357
# 3      1.029949  1.666584 -0.446576
# 4     -0.781956 -0.934594  0.284863
# ..          ...       ...       ...
# 194    0.826968 -0.121726  2.084347
# 195   -0.839572 -0.609447 -0.641459
# 196   -1.383486 -1.584888 -0.459940
# 197   -0.811945 -0.609447 -0.303440
# 198    0.704589  0.528568  0.355222
#
# [199 rows x 3 columns]

# %%
# Compute similarity
feature_matrix = customer_features.drop(columns=["CustomerID"])
similarity_matrix = cosine_similarity(feature_matrix)
print(feature_matrix)
print(similarity_matrix)
# Out:
#      TotalValue  Quantity   Price_x  Category  Region
# 0     -0.061546 -0.121726  0.094432       155       3
# 1     -0.875535 -0.446873 -0.901742       170       0
# 2     -0.404836  0.203421 -1.091357        69       3
# 3      1.029949  1.666584 -0.446576       110       3
# 4     -0.781956 -0.934594  0.284863       116       0
# ..          ...       ...       ...       ...     ...
# 194    0.826968 -0.121726  2.084347       160       1
# 195   -0.839572 -0.609447 -0.641459       151       1
# 196   -1.383486 -1.584888 -0.459940        59       1
# 197   -0.811945 -0.609447 -0.303440       123       1
# 198    0.704589  0.528568  0.355222        83       0
#
# [199 rows x 5 columns]
# [[1.         0.99978227 0.99955317 ... 0.99935692 0.99990436 0.99974096]
#  [0.99978227 1.         0.99898546 ... 0.99939301 0.99995917 0.9998206 ]
#  [0.99955317 0.99898546 1.         ... 0.99901894 0.99925603 0.99874596]
#  ...
#  [0.99935692 0.99939301 0.99901894 ... 1.         0.99956567 0.99872269]
#  [0.99990436 0.99995917 0.99925603 ... 0.99956567 1.         0.99976626]
#  [0.99974096 0.9998206  0.99874596 ... 0.99872269 0.99976626 1.        ]]

# %%
# Generate Lookalike Recommendations
lookalike_results = {}
for idx, customer_id in enumerate(customer_features["CustomerID"]):
    similarity_scores = list(enumerate(similarity_matrix[idx]))
    similar_customers = sorted(similarity_scores, key=lambda x: x[1], reverse=True)[1:4]  # Top 3 similar customers
    lookalike_results[customer_id] = [(customer_features.iloc[i[0]]["CustomerID"], i[1]) for i in similar_customers]

# %%
# Prepare Lookalike.csv
lookalike_list = []
for cust_id, recommendations in lookalike_results.items():
    for rec in recommendations:
        lookalike_list.append({"CustomerID": cust_id, "SimilarCustomerID": rec[0], "Score": rec[1]})
print(lookalike_list)
# Out:
# [{'CustomerID': 'C0001', 'SimilarCustomerID': 'C0152', 'Score': 0.9999971019111189}, {'CustomerID': 'C0001', 'SimilarCustomerID': 'C0181', 'Score': 0.9999931087277139}, {'CustomerID': 'C0001', 'SimilarCustomerID': 'C0133', 'Score': 0.9999930182385431}, {'CustomerID': 'C0002', 'SimilarCustomerID': 'C0027', 'Score': 0.9999988685147337}, {'CustomerID': 'C0002', 'SimilarCustomerID': 'C0178', 'Score': 0.9999955317324155}, {'CustomerID': 'C0002', 'SimilarCustomerID': 'C0177', 'Score': 0.9999890630040126}, {'CustomerID': 'C0003', 'SimilarCustomerID': 'C0034', 'Score': 0.999909781189737}, {'CustomerID': 'C0003', 'SimilarCustomerID': 'C0030', 'Score': 0.9999091999410602}, {'CustomerID': 'C0003', 'SimilarCustomerID': 'C0031', 'Score': 0.9999039909102194}, {'CustomerID': 'C0004', 'SimilarCustomerID': 'C0102', 'Score': 0.9999616098352663}, {'CustomerID': 'C0004', 'SimilarCustomerID': 'C0113', 'Score': 0.9999600104531012}, {'CustomerID': 'C0004', 'SimilarCustomerID': 'C0163', 'Score': 0.9999479831509901}, {'CustomerID': 'C0005', 'SimilarCustomerID': 'C0140', 'Score': 0.99999906874764}, {'CustomerID': 'C0005', 'SimilarCustomerID': 'C0128', 'Score': 0.999994495114212}, {'CustomerID': 'C0005', 'SimilarCustomerID': 'C0123', 'Score': 0.9999920247998791}, {'CustomerID': 'C0006', 'SimilarCustomerID': 'C0183', 'Score': 0.9999959699758956}, {'CustomerID': 'C0006', 'SimilarCustomerID': 'C0048', 'Score': 0.9999911608603738}, {'CustomerID': 'C0006', 'SimilarCustomerID': 'C0133', 'Score': 0.9999767220360424}, {'CustomerID': 'C0007', 'SimilarCustomerID': 'C0146', 'Score': 0.9999977804370052}, {'CustomerID': 'C0007', 'SimilarCustomerID': 'C0092', 'Score': 0.9999777541326107}, {'CustomerID': 'C0007', 'SimilarCustomerID': 'C0089', 'Score': 0.9999746625055287}, {'CustomerID': 'C0008', 'SimilarCustomerID': 'C0113', 'Score': 0.9999893503921391}, {'CustomerID': 'C0008', 'SimilarCustomerID': 'C0057', 'Score': 0.9999728073834576}, {'CustomerID': 'C0008', 'SimilarCustomerID': 'C0039', 'Score': 0.9999662240051013}, {'CustomerID': 'C0009', 'SimilarCustomerID': 'C0061', 'Score': 0.9999531015433426}, {'CustomerID': 'C0009', 'SimilarCustomerID': 'C0020', 'Score': 0.9999180355654474}, {'CustomerID': 'C0009', 'SimilarCustomerID': 'C0167', 'Score': 0.9999129668051591}, {'CustomerID': 'C0010', 'SimilarCustomerID': 'C0033', 'Score': 0.999377419568825}, {'CustomerID': 'C0010', 'SimilarCustomerID': 'C0142', 'Score': 0.9988496636304125}, {'CustomerID': 'C0010', 'SimilarCustomerID': 'C0032', 'Score': 0.9983225197013562}, {'CustomerID': 'C0011', 'SimilarCustomerID': 'C0107', 'Score': 0.9994386630760068}, {'CustomerID': 'C0011', 'SimilarCustomerID': 'C0153', 'Score': 0.9987314362868459}, {'CustomerID': 'C0011', 'SimilarCustomerID': 'C0013', 'Score': 0.9976109831720504}, {'CustomerID': 'C0012', 'SimilarCustomerID': 'C0153', 'Score': 0.9951000128255265}, {'CustomerID': 'C0012', 'SimilarCustomerID': 'C0018', 'Score': 0.9940127645208515}, {'CustomerID': 'C0012', 'SimilarCustomerID': 'C0046', 'Score': 0.9935020818631717}, {'CustomerID': 'C0013', 'SimilarCustomerID': 'C0046', 'Score': 0.9990389834966661}, {'CustomerID': 'C0013', 'SimilarCustomerID': 'C0153', 'Score': 0.9984205013796503}, {'CustomerID': 'C0013', 'SimilarCustomerID': 'C0018', 'Score': 0.998357824781911}, {'CustomerID': 'C0014', 'SimilarCustomerID': 'C0119', 'Score': 0.9999710923995194}, {'CustomerID': 'C0014', 'SimilarCustomerID': 'C0097', 'Score': 0.9999643094758376}, {'CustomerID': 'C0014', 'SimilarCustomerID': 'C0121', 'Score': 0.9999514277245077}, {'CustomerID': 'C0015', 'SimilarCustomerID': 'C0058', 'Score': 0.9998883047391511}, {'CustomerID': 'C0015', 'SimilarCustomerID': 'C0150', 'Score': 0.999528194647577}, {'CustomerID': 'C0015', 'SimilarCustomerID': 'C0042', 'Score': 0.999370652909063}, {'CustomerID': 'C0016', 'SimilarCustomerID': 'C0079', 'Score': 0.9999494117901022}, {'CustomerID': 'C0016', 'SimilarCustomerID': 'C0158', 'Score': 0.9999243967828051}, {'CustomerID': 'C0016', 'SimilarCustomerID': 'C0050', 'Scor ...

# %%
lookalike_df = pd.DataFrame(lookalike_list)
lookalike_df.to_csv("Lookalike.csv", index=False)

print("Lookalike model completed and Lookalike.csv saved!")
# Out:
# Lookalike model completed and Lookalike.csv saved!
